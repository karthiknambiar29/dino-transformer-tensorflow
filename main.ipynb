# %%
import vision_transformer as vits
from utils import *

# %%
arch = 'vit_small'
patch_size = 8
model = vits.__dict__[arch](patch_size=patch_size)
model.load_weights('models/' + arch + str(patch_size))
# Out:
# input shape: (1, 224, 224, 3)
# patch_embed: (1, 784, 384)
# cls_token: (1, 1, 384)
# embedding: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# block: (1, 785, 384)
# out_dim: (1, 384)

# %%
model(np.random.randn(1, 480, 480, 3)).shape
# Out:
# input shape: (1, 480, 480, 3)
# patch_embed: (1, 3600, 384)
# cls_token: (1, 1, 384)
# embedding: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# block: (1, 3601, 384)
# out_dim: (1, 384)
# TensorShape([1, 384])

# %%
image_paths = ['images/cat.jpg',
               'images/img.png',
               'images/test.jpg']

attentions = plot_attention(model, image_paths, patch_size, print_head=-1, save_fig=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attentions = plot_attention(model, image_paths, patch_size, print_head='all')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
attentions = plot_attention(model, image_paths, patch_size, print_head='average')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
